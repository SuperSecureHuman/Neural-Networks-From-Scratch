# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
import matplotlib.pyplot as plt

#Plot styling
import seaborn
from matplotlib import style
plt.style.use('seaborn')
#Plot styling end

# %% [markdown]
# nnfs.init() does the following:
# * Set random seed to 0
# * Sets float32 to be default data type
# * Overrides original dot product family from numpy

# %%
nnfs.init()

# %%
# %matplotlib inline
X, y = spiral_data(samples=100, classes=3)
plt.figure(figsize=(3.81*3,2.48*3)) #Enlarging the plot by a bit
plt.scatter(X[:,0], X[:,1])

# %%
# %matplotlib inline
X, y = spiral_data(samples=100, classes=3)
plt.figure(figsize=(3.81*3,2.48*3)) #Enlarging the plot by a bit
plt.scatter(X[:,0], X[:,1],c=y, cmap='brg')
